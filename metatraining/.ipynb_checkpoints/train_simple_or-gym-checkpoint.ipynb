# %% [markdown]
# # MIRACL / Meta-HMORL on OR-Gym-style Simple Supply Chain
#
# This notebook is a cleaned version of `metah_s2_5000ts_orgym.ipynb` that uses `simple_state.py` instead of the Messiah-based `SimpleSC` / `TestSimpleSC` imports.
# It supports:
#
# - RLlib/MAML meta-training with the OR-Gym-style `SimpleState` environment.
# - Stable-Baselines3 PPO fine-tuning on the fixed-demand `TestSimpleState` environment.
# - Native evaluation using the `info["mo_reward"]` and `info["mo_reward_raw"]` fields returned by `simple_state.py`.
#
# Place `simple_state.py` in the same directory as this notebook, or set `ORGym_ENV_DIR` below.

# %%
# ---------------------------------------------------------------------
# 0. Paths and runtime settings
# ---------------------------------------------------------------------
import os
import sys
from pathlib import Path

# Main project directory containing algo_ray, utils, etc.
MIRACL_BASE_DIR = Path(os.environ.get("MIRACL_BASE_DIR", "/home/rifnyrachman7/_metamorl"))

# Directory containing simple_state.py.  In ChatGPT sandbox this is /mnt/data.
ORGYM_ENV_DIR = Path(os.environ.get("ORGYM_ENV_DIR", "/mnt/data"))

for p in [MIRACL_BASE_DIR, ORGYM_ENV_DIR, Path.cwd()]:
    p = Path(p)
    if p.exists() and str(p) not in sys.path:
        sys.path.insert(0, str(p))

# Keep PYTHONPATH additive instead of overwriting it.
os.environ["PYTHONPATH"] = os.pathsep.join(
    [str(MIRACL_BASE_DIR), str(ORGYM_ENV_DIR), os.environ.get("PYTHONPATH", "")]
)

# Output directories. Change these if needed.
EXP_NAME = "metah_s2_orgym_5000ts"
CKPT_DIR = MIRACL_BASE_DIR / "mo_train" / EXP_NAME
FT_DIR = MIRACL_BASE_DIR / "fine_tuning" / EXP_NAME
PERF_DIR = FT_DIR / "performance"
for d in [CKPT_DIR, FT_DIR, PERF_DIR]:
    d.mkdir(parents=True, exist_ok=True)

NUM_PERIODS = 100
ROLLOUT_FRAGMENT_LENGTH = 32
TOTAL_STEPS = 5000
RECORD_EVERY = 250
EVAL_EPISODES = 50
RUNS = 10

print("MIRACL_BASE_DIR:", MIRACL_BASE_DIR)
print("ORGYM_ENV_DIR:", ORGYM_ENV_DIR)
print("CKPT_DIR:", CKPT_DIR)
print("FT_DIR:", FT_DIR)
# Out:
# MIRACL_BASE_DIR: /home/rifnyrachman7/_metamorl
# ORGYM_ENV_DIR: /mnt/data
# CKPT_DIR: /home/rifnyrachman7/_metamorl/mo_train/metah_s2_orgym_5000ts
# FT_DIR: /home/rifnyrachman7/_metamorl/fine_tuning/metah_s2_orgym_5000ts

# %%
# ---------------------------------------------------------------------
# 1. Imports
# ---------------------------------------------------------------------
import time
import copy
import warnings
import tempfile

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    import pygmo as pg
except Exception as exc:
    pg = None
    warnings.warn(f"pygmo is unavailable; hypervolume cells will not run until installed. Error: {exc}")

import gymnasium as gym
from gymnasium.wrappers import TimeLimit

import ray
from ray import air, tune
from ray.air import Checkpoint
from ray.tune.registry import register_env

from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.monitor import Monitor

# Local MIRACL/RLlib algorithm.
from algo_ray.rllib.algorithms.maml.maml_psa import MAMLPsa, MAMLConfigPsa

# OR-Gym-style simple SC environment.
from simple_state import make_env, SimpleState, TestSimpleState

print("Imports loaded")
# Out:
# 2026-05-07 07:40:29.819079: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-07 07:40:29.830558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778139629.844821   37520 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778139629.849167   37520 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-07 07:40:29.863744: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 35
#      32 from algo_ray.rllib.algorithms.maml.maml_psa import MAMLPsa, MAMLConfigPsa
#      34 # OR-Gym-style simple SC environment.
# ---> 35 from simple_state import make_env, SimpleState, TestSimpleState
#      37 print("Imports loaded")
#
# ModuleNotFoundError: No module named 'simple_state'

# %%
# ---------------------------------------------------------------------
# 2. Simple-state smoke test
# ---------------------------------------------------------------------
train_env_smoke = make_env({"fixed_demand": False, "num_periods": NUM_PERIODS, "seed": 0})
ft_env_smoke = make_env({"fixed_demand": True, "num_periods": NUM_PERIODS, "seed": 0})

obs, info = ft_env_smoke.reset(seed=0)
obs2, reward, terminated, truncated, info2 = ft_env_smoke.step(ft_env_smoke.action_space.sample())

print("Train env:", type(train_env_smoke).__name__)
print("FT env:", type(ft_env_smoke).__name__)
print("action_space:", ft_env_smoke.action_space)
print("observation_space:", ft_env_smoke.observation_space)
print("first reward:", reward)
print("mo_reward:", info2.get("mo_reward"))
print("mo_reward_raw:", info2.get("mo_reward_raw"))

# %%
# ---------------------------------------------------------------------
# 3. RLlib environment registration
# ---------------------------------------------------------------------
TRAIN_ENV_ID = "miracl_simple_train_orgym"
FT_ENV_ID = "miracl_simple_ft_orgym"


def make_train_env(env_config=None):
    cfg = dict(env_config or {})
    cfg.setdefault("fixed_demand", False)
    cfg.setdefault("num_periods", NUM_PERIODS)
    env = make_env(cfg)
    return TimeLimit(env, max_episode_steps=cfg["num_periods"])


def make_ft_env(env_config=None):
    cfg = dict(env_config or {})
    cfg.setdefault("fixed_demand", True)
    cfg.setdefault("num_periods", NUM_PERIODS)
    cfg.setdefault("randomise_costs", False)
    cfg.setdefault("randomise_demand", False)
    env = make_env(cfg)
    return TimeLimit(env, max_episode_steps=cfg["num_periods"])

register_env(TRAIN_ENV_ID, make_train_env)
register_env(FT_ENV_ID, make_ft_env)

print("Registered RLlib envs:", TRAIN_ENV_ID, FT_ENV_ID)

# %% [markdown]
# ## Meta-training phase
#
# Set `RUN_META_TRAINING=True` to run full training.  The default is `False` so the notebook can be opened and smoke-tested without launching a long Ray job.

# %%
# ---------------------------------------------------------------------
# 4. MAML/PSA meta-training config
# ---------------------------------------------------------------------
ray.shutdown()
ray.init(ignore_reinit_error=True)

meta_config = (
    MAMLConfigPsa()
    .rollouts(num_rollout_workers=4, rollout_fragment_length=ROLLOUT_FRAGMENT_LENGTH)
    .framework("torch")
    .environment(TRAIN_ENV_ID, clip_actions=True, env_config={"fixed_demand": False, "num_periods": NUM_PERIODS})
    .training(
        inner_adaptation_steps=4,
        maml_optimizer_steps=10,
        gamma=0.99,
        lambda_=1.0,
        lr=0.001,
        vf_loss_coeff=0.5,
        inner_lr=0.003,   # paper setting; change to 0.03 only if restoring old checkpoints trained that way
        use_meta_env=True,
        clip_param=0.3,
        kl_target=0.01,
        kl_coeff=0.001,
        model=dict(fcnet_hiddens=[64, 64], fcnet_activation="tanh"),
        train_batch_size=ROLLOUT_FRAGMENT_LENGTH,
    )
    .evaluation(
        evaluation_num_workers=1,
        evaluation_interval=100,
        enable_async_evaluation=True,
    )
)

meta_config.to_dict()["env"]

# %%
# ---------------------------------------------------------------------
# 5. Run meta-training and save one checkpoint per run
# ---------------------------------------------------------------------
RUN_META_TRAINING = False
NUM_ITERATIONS = 250  # 250 * 4 workers * 32 fragment length is a small run; adjust for your target budget.

meta_results = {}

if RUN_META_TRAINING:
    for run_id in range(RUNS):
        print(f"RUNNING META-TRAINING {run_id}")
        tuner = tune.Tuner(
            MAMLPsa,
            param_space=meta_config.to_dict(),
            run_config=air.RunConfig(
                stop={"training_iteration": NUM_ITERATIONS},
                failure_config=air.FailureConfig(fail_fast="raise"),
                log_to_file=True,
            ),
        )
        result_grid = tuner.fit()
        meta_results[run_id] = result_grid

        best_result = result_grid.get_best_result()
        run_ckpt = CKPT_DIR / f"run_{run_id}_metapolicy"
        run_ckpt.mkdir(parents=True, exist_ok=True)
        best_result.checkpoint.to_directory(str(run_ckpt))
        print(f"Best checkpoint for run {run_id} stored in: {run_ckpt}")
else:
    print("RUN_META_TRAINING=False; skipping meta-training.")

# %% [markdown]
# ## Fine-tuning phase with Stable-Baselines3 PPO
#
# This section restores each RLlib meta-policy checkpoint (if available), starts an SB3 PPO policy on the OR-Gym-style fixed-demand environment, and evaluates vector returns from `simple_state.py`.

# %%
# ---------------------------------------------------------------------
# 6. Utilities: weights, evaluation, and optional RLlib -> SB3 warm start
# ---------------------------------------------------------------------
WEIGHT_GRID_21 = np.array([
    [0.0, 0.0, 1.0], [0.0, 0.2, 0.8], [0.0, 0.4, 0.6], [0.0, 0.6, 0.4], [0.0, 0.8, 0.2],
    [0.0, 1.0, 0.0], [0.2, 0.0, 0.8], [0.2, 0.2, 0.6], [0.2, 0.4, 0.4], [0.2, 0.6, 0.2],
    [0.2, 0.8, 0.0], [0.4, 0.0, 0.6], [0.4, 0.2, 0.4], [0.4, 0.4, 0.2], [0.4, 0.6, 0.0],
    [0.6, 0.0, 0.4], [0.6, 0.2, 0.2], [0.6, 0.4, 0.0], [0.8, 0.0, 0.2], [0.8, 0.2, 0.0],
    [1.0, 0.0, 0.0],
], dtype=np.float64)


def set_env_weights(env, weights):
    """Set scalarisation weights through Monitor/TimeLimit wrappers if needed."""
    target = env
    while hasattr(target, "env"):
        if hasattr(target, "set_scalarization_weights"):
            break
        target = target.env
    if hasattr(target, "set_scalarization_weights"):
        target.set_scalarization_weights(weights)
    else:
        raise AttributeError("Could not find set_scalarization_weights on env or wrapped env.")


def make_sb3_env(weights, seed=None):
    env = make_env({
        "fixed_demand": True,
        "num_periods": NUM_PERIODS,
        "weights": np.asarray(weights, dtype=np.float64),
        "seed": seed,
        "normalize_actions": True,      # important
        "max_order_quantity": 500.0,
    })
    return Monitor(env)


def evaluate_model(model, weights, n_eval_episodes=50, seed=123):
    """Evaluate an SB3 model and return scalar and vector-return statistics.

    Returns raw vector returns in the convention of simple_state.py:
    [profit, -emission, -service_inequality].
    """
    scalar_returns = []
    raw_returns = []
    norm_returns = []

    for ep in range(n_eval_episodes):
        env = make_sb3_env(weights, seed=None if seed is None else seed + ep)
        obs, info = env.reset(seed=None if seed is None else seed + ep)
        done = False
        scalar_total = 0.0
        raw_total = np.zeros(3, dtype=np.float64)
        norm_total = np.zeros(3, dtype=np.float64)

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            done = bool(terminated or truncated)
            scalar_total += float(reward)
            raw_total += np.asarray(info.get("mo_reward_raw", np.zeros(3)), dtype=np.float64)
            norm_total += np.asarray(info.get("mo_reward", np.zeros(3)), dtype=np.float64)

        scalar_returns.append(scalar_total)
        raw_returns.append(raw_total)
        norm_returns.append(norm_total)
        env.close()

    scalar_returns = np.asarray(scalar_returns, dtype=np.float64)
    raw_returns = np.asarray(raw_returns, dtype=np.float64)
    norm_returns = np.asarray(norm_returns, dtype=np.float64)

    return {
        "mean_scalar": float(scalar_returns.mean()),
        "std_scalar": float(scalar_returns.std(ddof=1)) if len(scalar_returns) > 1 else 0.0,
        "mean_raw_vec": raw_returns.mean(axis=0),
        "std_raw_vec": raw_returns.std(axis=0, ddof=1) if len(raw_returns) > 1 else np.zeros(3),
        "mean_norm_vec": norm_returns.mean(axis=0),
        "std_norm_vec": norm_returns.std(axis=0, ddof=1) if len(norm_returns) > 1 else np.zeros(3),
    }


def build_restored_maml_trainer(checkpoint_path):
    """Build and restore the RLlib MAML trainer for a saved checkpoint."""
    checkpoint_path = Path(checkpoint_path)
    if not checkpoint_path.exists():
        raise FileNotFoundError(f"Checkpoint path does not exist: {checkpoint_path}")

    trainer = meta_config.build()
    trainer.restore(str(checkpoint_path))
    return trainer


def warm_start_sb3_from_rllib(sb3_model, rllib_trainer):
    """Best-effort copy of matching torch parameters from RLlib to SB3.

    RLlib and SB3 often use different module names, so this function only copies
    parameters with identical keys and shapes. If nothing matches, training still
    runs from the SB3 initialisation and a warning is printed.
    """
    if rllib_trainer is None:
        return 0
    try:
        ray_state = rllib_trainer.get_policy().model.state_dict()
        sb3_state = sb3_model.policy.state_dict()
        copied = 0
        for key, value in ray_state.items():
            if key in sb3_state and tuple(value.shape) == tuple(sb3_state[key].shape):
                sb3_state[key] = value.detach().cpu()
                copied += 1
        if copied:
            sb3_model.policy.load_state_dict(sb3_state)
        else:
            warnings.warn("No matching RLlib/SB3 parameter names found; SB3 policy starts from its own initialisation.")
        return copied
    except Exception as exc:
        warnings.warn(f"Could not warm-start SB3 from RLlib checkpoint: {exc}")
        return 0

# %%
# ---------------------------------------------------------------------
# 7. Fine-tune one or more checkpoints with SB3 PPO
# ---------------------------------------------------------------------
RUN_FINE_TUNING = True
FT_TOTAL_TIMESTEPS = 5000
N_SEEDS = 3
WEIGHT_GRID = WEIGHT_GRID_21[:3]
USE_RLLIB_WARM_START = False

n_records = int(TOTAL_STEPS / RECORD_EVERY)
episode_num = np.linspace(RECORD_EVERY, TOTAL_STEPS, n_records, dtype=int)

if RUN_FINE_TUNING:
    for run_id in range(RUNS):
        ray.shutdown()
        ray.init(ignore_reinit_error=True)
        register_env(TRAIN_ENV_ID, make_train_env)
        register_env(FT_ENV_ID, make_ft_env)

        ckpt_path = CKPT_DIR / f"run_{run_id}_metapolicy"
        rllib_trainer = None
        if USE_RLLIB_WARM_START and ckpt_path.exists():
            print(f"Restoring RLlib checkpoint: {ckpt_path}")
            rllib_trainer = build_restored_maml_trainer(ckpt_path)
        elif USE_RLLIB_WARM_START:
            warnings.warn(f"Checkpoint not found for run {run_id}: {ckpt_path}. Running SB3 from scratch.")

        print(f"RUNNING FINE-TUNING RUN {run_id}")
        start = time.time()

        mean_reward_history = np.zeros((WEIGHT_GRID_21.shape[0], n_records))
        std_reward_history = np.zeros((WEIGHT_GRID_21.shape[0], n_records))
        mean_profit_hist = np.zeros((WEIGHT_GRID_21.shape[0], n_records))
        mean_emission_hist = np.zeros((WEIGHT_GRID_21.shape[0], n_records))
        mean_equity_hist = np.zeros((WEIGHT_GRID_21.shape[0], n_records))

        for weight_id, weights in enumerate(WEIGHT_GRID_21):
            print(f"start training solution {weight_id}, weights={weights}")
            env = make_sb3_env(weights, seed=run_id)
            model = PPO(
                MlpPolicy,
                env,
                verbose=0,
                learning_rate=3e-4,
                n_steps=2048,
                batch_size=64,
                n_epochs=10,
                gamma=0.99,
                gae_lambda=0.95,
                clip_range=0.2,
                ent_coef=0.0,
                vf_coef=0.5,
                max_grad_norm=0.5,
                policy_kwargs=dict(net_arch=[64, 64]),
                seed=run_id,
            )
            copied = warm_start_sb3_from_rllib(model, rllib_trainer)
            if copied:
                print(f"Copied {copied} matching tensors from RLlib to SB3")

            for rec_id in range(n_records):
                model.learn(total_timesteps=RECORD_EVERY, reset_num_timesteps=False)
                stats = evaluate_model(model, weights, n_eval_episodes=EVAL_EPISODES, seed=10_000 + run_id * 1000 + weight_id * 10)

                mean_reward_history[weight_id, rec_id] = stats["mean_scalar"]
                std_reward_history[weight_id, rec_id] = stats["std_scalar"]
                mean_profit_hist[weight_id, rec_id] = stats["mean_raw_vec"][0]
                mean_emission_hist[weight_id, rec_id] = stats["mean_raw_vec"][1]
                mean_equity_hist[weight_id, rec_id] = stats["mean_raw_vec"][2]

                print(
                    f"  step={episode_num[rec_id]} scalar={stats['mean_scalar']:.3f} "
                    f"vec={stats['mean_raw_vec']}"
                )

            model_file = FT_DIR / f"run_{run_id}_solution_{weight_id}.zip"
            model.save(str(model_file))
            env.close()

        print(f"Training time for run {run_id}: {time.time() - start:.1f} seconds")
        print("=" * 50)

        pd.DataFrame(WEIGHT_GRID_21).to_csv(FT_DIR / f"{run_id}.weight_list.csv", index=False)
        pd.DataFrame(mean_reward_history).to_csv(FT_DIR / f"{run_id}.mean_reward.csv", index=False)
        pd.DataFrame(std_reward_history).to_csv(FT_DIR / f"{run_id}.std_reward.csv", index=False)
        pd.DataFrame(mean_profit_hist).to_csv(FT_DIR / f"{run_id}.profit_reward.csv", index=False)
        pd.DataFrame(mean_emission_hist).to_csv(FT_DIR / f"{run_id}.emission_reward.csv", index=False)
        pd.DataFrame(mean_equity_hist).to_csv(FT_DIR / f"{run_id}.equity_reward.csv", index=False)

    print("ALL RUNS DONE")
else:
    print("RUN_FINE_TUNING=False; skipping SB3 fine-tuning.")
# Out:
# 2026-05-07 02:30:00,827	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-05-07 02:30:00,829	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-05-07 02:30:00,830	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67104768 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-05-07 02:30:00,877	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# RUNNING FINE-TUNING RUN 0
# start training solution 0, weights=[0. 0. 1.]
#   step=250 scalar=-2.435 vec=[-1.76346698e+04 -1.73186445e+03 -2.43528532e+00]
#   step=500 scalar=-4.502 vec=[-2.06529751e+04 -1.09756904e+04 -4.50172780e+00]
#   step=750 scalar=-3.686 vec=[-4.40880956e+04 -1.46140563e+04 -3.68588987e+00]
#   step=1000 scalar=-7.916 vec=[ 9.16397497e+03 -1.84950147e+04 -7.91555751e+00]
#   step=1250 scalar=-8.341 vec=[ 1.19099496e+03 -2.36398130e+04 -8.34089487e+00]
#   step=1500 scalar=-14.085 vec=[ 1.56160502e+04 -3.07904511e+04 -1.40851481e+01]
#   step=1750 scalar=-12.369 vec=[-1.04864053e+04 -3.52294987e+04 -1.23690970e+01]
#   step=2000 scalar=-13.867 vec=[-1.27724295e+04 -4.30091716e+04 -1.38669209e+01]
#   step=2250 scalar=-12.012 vec=[-1.73875046e+03 -3.67619713e+04 -1.20117596e+01]
#   step=2500 scalar=-10.186 vec=[-2.27053796e+04 -4.74932765e+04 -1.01863897e+01]
#   step=2750 scalar=-12.059 vec=[-2.61399501e+04 -5.93766414e+04 -1.20585411e+01]
#   step=3000 scalar=-13.526 vec=[ 3.83139198e+04 -5.85421437e+04 -1.35258113e+01]
#   step=3250 scalar=-13.673 vec=[ 2.62245752e+04 -6.38392675e+04 -1.36734691e+01]
#   step=3500 scalar=-10.668 vec=[-4.98437251e+04 -7.80562239e+04 -1.06680846e+01]
#   step=3750 scalar=-21.478 vec=[ 2.08276415e+05 -8.57916770e+04 -2.14779464e+01]
#   step=4000 scalar=-13.870 vec=[-4.86115700e+04 -8.78218019e+04 -1.38704652e+01]
#   step=4250 scalar=-14.499 vec=[-1.80872706e+04 -9.22015668e+04 -1.44993804e+01]
#   step=4500 scalar=-19.366 vec=[ 6.35058253e+04 -9.06654147e+04 -1.93661464e+01]
#   step=4750 scalar=-20.807 vec=[ 2.65580685e+05 -1.05188133e+05 -2.08074686e+01]
#   step=5000 scalar=-18.915 vec=[ 2.95256569e+05 -1.17260695e+05 -1.89148901e+01]
# start training solution 1, weights=[0.  0.2 0.8]
#   step=250 scalar=-2.335 vec=[-4.46716496e+04 -1.57954108e+04 -2.72139308e+00]
#   step=500 scalar=-2.371 vec=[-3.25426697e+04 -1.29972713e+04 -2.80221169e+00]
#   step=1500 scalar=4.616 vec=[ 5.66845502e+04 -2.00199521e+04 -1.56986349e+01]
#   step=1750 scalar=5.158 vec=[ 6.33347599e+04 -2.49121724e+04 -1.60843107e+01]
#   step=2000 scalar=3.326 vec=[ 4.08423154e+04 -1.93883743e+04 -1.22282441e+01]
#   step=2250 scalar=4.583 vec=[ 5.62758849e+04 -2.19903115e+04 -1.63809438e+01]
#   step=2500 scalar=5.901 vec=[ 7.24629298e+04 -2.60302428e+04 -1.88503239e+01]
#   step=2750 scalar=3.857 vec=[ 4.73612400e+04 -1.61618784e+04 -1.17663370e+01]
#   step=3000 scalar=3.590 vec=[ 4.40854954e+04 -1.55532620e+04 -1.23914494e+01]
#   step=3250 scalar=6.134 vec=[ 7.53284654e+04 -2.68534792e+04 -1.90868874e+01]
#   step=3500 scalar=5.800 vec=[ 7.12259595e+04 -2.58928534e+04 -1.88361984e+01]
#   step=3750 scalar=6.263 vec=[ 7.69102855e+04 -2.52348645e+04 -2.01646177e+01]
#   step=4000 scalar=9.225 vec=[ 1.13284449e+05 -3.92578132e+04 -2.66049834e+01]
#   step=4250 scalar=1.753 vec=[ 2.15304307e+04 -1.22232177e+04 -9.13275738e+00]
#   step=4500 scalar=7.590 vec=[ 9.31996905e+04 -8.48600550e+04 -2.93145050e+01]
#   step=4750 scalar=3.887 vec=[ 4.77279400e+04 -1.91448680e+04 -1.38115797e+01]
#   step=5000 scalar=3.872 vec=[ 4.75468758e+04 -1.68629608e+04 -1.18629710e+01]
# Training time for run 0: 2963.6 seconds
# ==================================================
# 2026-05-07 03:19:29,748	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-05-07 03:19:29,749	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-05-07 03:19:29,750	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67104768 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-05-07 03:19:29,797	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# RUNNING FINE-TUNING RUN 1
# start training solution 0, weights=[0. 0. 1.]
#   step=250 scalar=-4.486 vec=[-5.93262098e+04 -1.93415729e+04 -4.48605417e+00]
#   step=500 scalar=-18.492 vec=[ 6.27754699e+04 -2.49577014e+04 -1.84918698e+01]
#   step=750 scalar=-17.588 vec=[ 1.24918035e+05 -4.83123180e+04 -1.75875319e+01]
#   step=1000 scalar=-19.045 vec=[ 1.36706440e+05 -5.07355271e+04 -1.90447777e+01]
#   step=1250 scalar=-19.233 vec=[ 1.53911340e+05 -5.28904997e+04 -1.92333228e+01]
#   step=1500 scalar=-22.792 vec=[ 1.28539130e+05 -4.40208147e+04 -2.27915260e+01]
#   step=1750 scalar=-22.471 vec=[ 1.67291785e+05 -6.28400817e+04 -2.24713296e+01]
#   step=2000 scalar=-23.661 vec=[ 1.95993245e+05 -7.38373790e+04 -2.36610698e+01]
#   step=2250 scalar=-24.825 vec=[ 1.70251965e+05 -8.08479507e+04 -2.48246046e+01]
#   step=2500 scalar=-21.409 vec=[ 2.47547324e+05 -8.51810483e+04 -2.14085445e+01]
#   step=2750 scalar=-18.216 vec=[ 2.36135826e+05 -8.19005495e+04 -1.82163952e+01]
#   step=3000 scalar=-19.461 vec=[ 2.16511626e+05 -7.36441324e+04 -1.94610258e+01]
#   step=3250 scalar=-20.548 vec=[ 2.17372289e+05 -7.81736382e+04 -2.05478856e+01]
#   step=3500 scalar=-17.827 vec=[ 2.51669959e+05 -8.76176951e+04 -1.78273822e+01]
#   step=3750 scalar=-14.819 vec=[ 2.80661371e+05 -9.90614420e+04 -1.48185572e+01]
#   step=4000 scalar=-17.799 vec=[ 3.13748935e+05 -1.09492934e+05 -1.77991055e+01]
#   step=4250 scalar=-17.082 vec=[ 2.99893379e+05 -1.12049349e+05 -1.70821781e+01]
#   step=4500 scalar=-20.383 vec=[ 2.63445110e+05 -1.01055314e+05 -2.03825878e+01]
#   step=4750 scalar=-19.125 vec=[ 3.04186755e+05 -1.07829164e+05 -1.91251113e+01]
#   step=5000 scalar=-18.113 vec=[ 2.80617230e+05 -1.02274161e+05 -1.81126110e+01]
# start training solution 1, weights=[0.  0.2 0.8]
#   step=250 scalar=-9.523 vec=[ 1.16340400e+04 -2.21788242e+04 -1.16266334e+01]
#   step=500 scalar=-16.114 vec=[ 6.07535302e+04 -2.73075646e+04 -1.98019033e+01]
#   step=750 scalar=-16.503 vec=[ 1.09072454e+05 -3.93664270e+04 -2.01378401e+01]
#   step=1000 scalar=-14.901 vec=[ 1.04181730e+05 -3.60073752e+04 -1.81774568e+01]
#   step=1250 scalar=-18.406 vec=[ 1.28036934e+05 -6.14574201e+04 -2.22415309e+01]
#   step=1500 scalar=-17.549 vec=[ 1.43249405e+05 -5.15108027e+04 -2.12938200e+01]
#   step=1750 scalar=-19.538 vec=[ 2.17462055e+05 -7.42498286e+04 -2.34967110e+01]
#   step=2000 scalar=-16.223 vec=[ 2.19331879e+05 -7.50951178e+04 -1.93421933e+01]
#   step=2250 scalar=-17.905 vec=[ 2.52841725e+05 -9.07031531e+04 -2.12504713e+01]
#   step=2500 scalar=-17.144 vec=[ 2.50362485e+05 -8.82608306e+04 -2.03289731e+01]
#   step=2750 scalar=-17.300 vec=[ 2.37043035e+05 -8.62671863e+04 -2.05496424e+01]
#   step=3000 scalar=-14.943 vec=[ 2.99297551e+05 -1.08737196e+05 -1.73229550e+01]
#   step=3250 scalar=-17.714 vec=[ 2.73899381e+05 -1.02346331e+05 -2.08664871e+01]
#   step=3500 scalar=-14.191 vec=[ 2.74773150e+05 -1.06510100e+05 -1.64102977e+01]
#   step=3750 scalar=-15.666 vec=[ 2.88798585e+05 -1.08182069e+05 -1.82338246e+01]
#   step=4000 scalar=-18.756 vec=[ 2.78956780e+05 -1.03768348e+05 -2.21511907e+01]
#   step=4250 scalar=-16.278 vec=[ 2.46983305e+05 -9.57110344e+04 -1.91543908e+01]
#   step=4500 scalar=-18.662 vec=[ 2.93158716e+05 -1.04005276e+05 -2.20304904e+01]
#   step=4750 scalar=-15.220 vec=[ 2.64713405e+05 -1.05634945e+05 -1.77079638e+01]
#   step=5000 scalar=-13.827 vec=[ 3.11649171e+05 -1.20043663e+05 -1.57872964e+01]
#   step=2250 scalar=-14.506 vec=[ 2.24876259e+05 -7.51022526e+04 -2.27103615e+01]
#   step=2500 scalar=-11.633 vec=[ 2.48790875e+05 -8.46673126e+04 -1.96059767e+01]
#   step=2750 scalar=-11.079 vec=[ 2.78272613e+05 -9.78434852e+04 -1.95145308e+01]
#   step=3000 scalar=-10.686 vec=[ 2.82277730e+05 -1.01660948e+05 -1.91047540e+01]
#   step=3250 scalar=-12.503 vec=[ 2.84769735e+05 -1.08398258e+05 -2.14257688e+01]
#   step=3500 scalar=-12.149 vec=[ 2.84217940e+05 -1.16508063e+05 -2.09723234e+01]
#   step=3750 scalar=-8.674 vec=[ 3.11478321e+05 -1.26293376e+05 -1.71831170e+01]
#   step=4000 scalar=-7.762 vec=[ 2.99417524e+05 -1.27853651e+05 -1.57987069e+01]
#   step=4250 scalar=-8.016 vec=[ 2.97218109e+05 -1.28714538e+05 -1.60708728e+01]
#   step=4500 scalar=-5.200 vec=[ 3.19693620e+05 -1.28710624e+05 -1.30086271e+01]
#   step=4750 scalar=-6.617 vec=[ 3.25130454e+05 -1.31154365e+05 -1.48904835e+01]
#   step=5000 scalar=-6.621 vec=[ 3.14906691e+05 -1.32092916e+05 -1.46873182e+01]
# start training solution 7, weights=[0.2 0.2 0.6]
#   step=250 scalar=-7.598 vec=[ 3.96933453e+04 -1.49369296e+04 -1.34920968e+01]
#   step=500 scalar=-8.618 vec=[ 3.67909150e+04 -1.51606964e+04 -1.51099226e+01]
#   step=750 scalar=-13.900 vec=[ 6.76208299e+04 -2.89438946e+04 -2.45205195e+01]
#   step=1000 scalar=-10.123 vec=[ 1.25230011e+05 -4.72983322e+04 -1.94849730e+01]
#   step=1250 scalar=-15.039 vec=[ 1.02193180e+05 -4.95513171e+04 -2.70147922e+01]
#   step=1500 scalar=-12.352 vec=[ 1.40699571e+05 -5.19060803e+04 -2.35421145e+01]
#   step=1750 scalar=-15.573 vec=[ 1.29977575e+05 -5.07995705e+04 -2.86385541e+01]
#   step=2000 scalar=-11.157 vec=[ 9.09020651e+04 -4.81716714e+04 -2.02622917e+01]
#   step=2250 scalar=-8.843 vec=[ 1.21534829e+05 -5.38722655e+04 -1.71421232e+01]
#   step=2500 scalar=-9.765 vec=[ 2.23227265e+05 -7.57777584e+04 -2.10748274e+01]
#   step=2750 scalar=-11.904 vec=[ 1.86916696e+05 -7.48039680e+04 -2.36709633e+01]
#   step=3000 scalar=-8.711 vec=[ 2.81773842e+05 -1.05119407e+05 -2.04199885e+01]
#   step=3250 scalar=-8.828 vec=[ 2.86174114e+05 -1.04522462e+05 -2.07433935e+01]
#   step=3500 scalar=-6.274 vec=[ 3.12947859e+05 -1.18805346e+05 -1.69764715e+01]
#   step=3750 scalar=-7.702 vec=[ 2.66561534e+05 -1.00592403e+05 -1.84005461e+01]
#   step=4000 scalar=-8.090 vec=[ 2.87861355e+05 -1.10244549e+05 -1.94647065e+01]
#   step=4250 scalar=-14.121 vec=[ 2.06969745e+05 -9.81793353e+04 -2.75206693e+01]
#   step=4500 scalar=-11.449 vec=[ 2.53610020e+05 -1.01059500e+05 -2.42863242e+01]
#   step=4750 scalar=-8.832 vec=[ 2.75788360e+05 -1.05529779e+05 -2.04522163e+01]
#   step=5000 scalar=-5.833 vec=[ 3.22627786e+05 -1.11074316e+05 -1.66324811e+01]
# start training solution 8, weights=[0.2 0.4 0.4]
#   step=250 scalar=-4.603 vec=[ 2.74923350e+04 -1.06845972e+04 -1.20943618e+01]
#   step=500 scalar=-5.062 vec=[ 4.44072099e+04 -2.23367743e+04 -1.33502879e+01]
#   step=750 scalar=-6.829 vec=[ 8.77959154e+04 -3.07539345e+04 -1.91126601e+01]
#   step=1000 scalar=-5.487 vec=[ 6.54493696e+04 -2.25027738e+04 -1.52591338e+01]
#   step=1250 scalar=-5.997 vec=[ 7.16614252e+04 -2.49355390e+04 -1.66668325e+01]
#   step=1500 scalar=-6.088 vec=[ 7.14257158e+04 -2.50131737e+04 -1.68814792e+01]
#   step=1750 scalar=-6.492 vec=[ 1.06215369e+05 -3.78781876e+04 -1.86657940e+01]
#   step=2000 scalar=-5.422 vec=[ 1.13438721e+05 -3.81229730e+04 -1.62722113e+01]
#   step=2250 scalar=-6.707 vec=[ 1.52782944e+05 -5.08204660e+04 -2.04525908e+01]
#   step=2500 scalar=-7.234 vec=[ 1.44105889e+05 -5.02530349e+04 -2.14458953e+01]
#   step=2750 scalar=-6.075 vec=[ 1.86978699e+05 -6.60791465e+04 -1.95057719e+01]
#   step=3000 scalar=-6.316 vec=[ 1.96108740e+05 -6.84421260e+04 -2.03625434e+01]
#   step=3250 scalar=-6.161 vec=[ 1.79454309e+05 -6.28351646e+04 -1.95752954e+01]
#   step=3500 scalar=-6.908 vec=[ 2.15804045e+05 -7.40033455e+04 -2.23647465e+01]
#   step=3750 scalar=-6.732 vec=[ 2.35438370e+05 -8.23801866e+04 -2.23065110e+01]
#   step=4000 scalar=-5.069 vec=[ 2.29507065e+05 -8.58737266e+04 -1.77341975e+01]
#   step=4250 scalar=-6.675 vec=[ 2.26121511e+05 -8.61127535e+04 -2.15987650e+01]
#   step=4500 scalar=-6.087 vec=[ 2.06437620e+05 -8.47932680e+04 -1.93938741e+01]
#   step=4750 scalar=-4.223 vec=[ 2.79452625e+05 -1.10372700e+05 -1.64321106e+01]
#   step=5000 scalar=-5.311 vec=[ 2.33255140e+05 -9.40897753e+04 -1.80814660e+01]
# start training solution 9, weights=[0.2 0.6 0.2]
#   step=250 scalar=-1.920 vec=[ 1.61805152e+04 -6.59757296e+03 -9.92829083e+00]
#   step=500 scalar=-1.903 vec=[ 9.79021016e+03 -1.71384799e+04 -7.75014338e+00]
#   step=750 scalar=-1.282 vec=[-1.79038852e+04 -3.00555230e+03 -4.50036059e+00]
#   step=1000 scalar=-1.229 vec=[-1.84153751e+04 -2.84973022e+03 -4.21823091e+00]
#   step=1250 scalar=-0.604 vec=[-436.1199646  -742.11209262   -2.87114175]
#   step=1500 scalar=-0.616 vec=[-6.21786509e+03 -9.92857517e+02 -2.42293373e+00]
#   step=4000 scalar=-0.181 vec=[-1.08565354e+04 -1.16707672e+02 -1.17713451e+00]
#   step=4250 scalar=-0.168 vec=[-1.00343896e+04 -1.18524904e+02 -1.74682847e+00]
#   step=4500 scalar=-0.153 vec=[-9.10005589e+03 -1.28221697e+02 -1.12069805e+00]
#   step=4750 scalar=-0.148 vec=[-8.69252010e+03 -1.50108455e+02 -1.26558442e+00]
#   step=5000 scalar=-0.161 vec=[-9.57482545e+03 -1.19170061e+02 -2.04219526e+00]
# start training solution 11, weights=[0.4 0.  0.6]
#   step=250 scalar=-5.407 vec=[ 2.21745947e+04 -9.03923751e+03 -1.02151272e+01]
#   step=500 scalar=-7.868 vec=[ 2.85831854e+04 -1.39937520e+04 -1.46652410e+01]
#   step=750 scalar=-10.299 vec=[ 5.72094053e+04 -2.19682209e+04 -2.02703915e+01]

# %% [markdown]
# ## Reload saved fine-tuning CSVs

# %%
# ---------------------------------------------------------------------
# 8. Reload fine-tuning results from CSV
# ---------------------------------------------------------------------
def load_fine_tuning_results(ft_dir=FT_DIR, runs=6):
    weight_list, mean_reward, std_reward = [], [], []
    profit_reward, emission_reward, equity_reward = [], [], []

    for run_id in range(runs):
        weight_list.append(pd.read_csv(ft_dir / f"{run_id}.weight_list.csv").to_numpy())
        mean_reward.append(pd.read_csv(ft_dir / f"{run_id}.mean_reward.csv").to_numpy())
        std_reward.append(pd.read_csv(ft_dir / f"{run_id}.std_reward.csv").to_numpy())
        profit_reward.append(pd.read_csv(ft_dir / f"{run_id}.profit_reward.csv").to_numpy())
        emission_reward.append(pd.read_csv(ft_dir / f"{run_id}.emission_reward.csv").to_numpy())
        equity_reward.append(pd.read_csv(ft_dir / f"{run_id}.equity_reward.csv").to_numpy())

    return {
        "weight_list": np.asarray(weight_list),
        "mean_reward": np.asarray(mean_reward),
        "std_reward": np.asarray(std_reward),
        "profit_reward": np.asarray(profit_reward),
        "emission_reward": np.asarray(emission_reward),
        "equity_reward": np.asarray(equity_reward),
    }

# Uncomment after running fine-tuning.
data = load_fine_tuning_results()
weight_list = data["weight_list"]
mean_reward = data["mean_reward"]
std_reward = data["std_reward"]
profit_reward = data["profit_reward"]
emission_reward = data["emission_reward"]
equity_reward = data["equity_reward"]

# %% [markdown]
# ## Performance metrics

# %%
#set reference value
min_point = np.array([0.0, -2e5, -1e2], dtype=np.float64)
max_point = np.array([4e5, 0.0, 0.0], dtype=np.float64)
ref_point = np.array([1,1,1])

# %%
norm_profit_reward, norm_emission_reward, norm_equity_reward = [np.empty(mean_reward.shape) for _ in range(3)]

# normalise rewards
for k in range(mean_reward.shape[0]): #runs
    for n in range(mean_reward.shape[1]): #weights
        for i in range(mean_reward.shape[2]): #iterations
            norm_profit_reward[k,n,i] = (profit_reward[k,n,i] - min_point[0])/(max_point[0]-min_point[0])
            norm_emission_reward[k,n,i] = (emission_reward[k,n,i] - min_point[1])/(max_point[1]-min_point[1])
            norm_equity_reward[k,n,i] = (equity_reward[k,n,i] - min_point[2])/(max_point[2]-min_point[2])

# %%
#inverse values (this is because pygmo uses max ref point instead of min like in MORLD)
reversed_profit_reward, reversed_emission_reward, reversed_equity_reward = [np.empty(mean_reward.shape) for _ in range(3)]

for k in range(mean_reward.shape[0]): #runs
    for n in range(mean_reward.shape[1]): #weights
        for i in range(mean_reward.shape[2]): #iterations
            reversed_profit_reward[k,n,i] = 1 - norm_profit_reward[k,n,i]
            reversed_emission_reward[k,n,i] = 1 - norm_emission_reward[k,n,i]
            reversed_equity_reward[k,n,i] = 1 - norm_equity_reward[k,n,i]

# %%
combined_rewards = np.stack([norm_profit_reward,norm_emission_reward,norm_equity_reward],axis=-1)
reversed_combined_rewards = np.stack([reversed_profit_reward,reversed_emission_reward,reversed_equity_reward],axis=-1)

# %%
#calculate Hypervolume
# Initialize the hypervolume lists
final_h = []

# Calculate hypervolumes using pygmo's hypervolume function
for k in range(reversed_combined_rewards.shape[0]): #runs
    h = []
    for i in range(reversed_combined_rewards.shape[2]): #iterations
        t = []
        for n in range(reversed_combined_rewards.shape[1]): #weights
            clipped_point = np.minimum(reversed_combined_rewards[k,n,i], ref_point - 1e-5) #clip the points within reference point
            # Aggregate data for all weights j at the current stage
            t.append(clipped_point)
        hv = pg.hypervolume(t)
        ref_point = ref_point
        h.append(hv.compute(ref_point))
    final_h.append(h)

# %%
#save hypervolume calculation into dataframe
df_h = pd.DataFrame(final_h)
df_h = df_h.T

df_h["mean"] = df_h.mean(axis=1)
df_h["std"] = df_h.std(axis=1)

# %%
df_h
# Out:
#            0         1         2         3         4         5      mean  \
# 0   0.015423  0.109055  0.051140  0.080095  0.055690  0.043036  0.059073
# 1   0.054771  0.134871  0.135435  0.092480  0.068147  0.066286  0.091998
# 2   0.067953  0.235484  0.208949  0.104073  0.172480  0.110682  0.149937
# 3   0.120232  0.251351  0.268021  0.125788  0.207507  0.146184  0.186514
# 4   0.164663  0.272931  0.229098  0.167243  0.229771  0.161782  0.204248
# 5   0.177684  0.260783  0.263316  0.211500  0.306824  0.257045  0.246192
# 6   0.212022  0.351935  0.322951  0.209552  0.328833  0.175618  0.266819
# 7   0.216023  0.366311  0.357328  0.313926  0.328897  0.169966  0.292075
# 8   0.291678  0.391021  0.393511  0.326056  0.340712  0.224928  0.327984
# 9   0.283890  0.385476  0.399310  0.325311  0.361405  0.194101  0.324915
# 10  0.303912  0.424600  0.433827  0.344666  0.339711  0.242745  0.348243
# 11  0.320041  0.437909  0.417391  0.348165  0.364760  0.258396  0.357777
# 12  0.337245  0.425007  0.406478  0.362908  0.381447  0.287239  0.366721
# 13  0.354086  0.458480  0.402784  0.407448  0.391196  0.300821  0.385802
# 14  0.382513  0.463581  0.387734  0.403215  0.410443  0.319352  0.394473
# 15  0.390841  0.453127  0.407660  0.420357  0.453308  0.323072  0.408061
# 16  0.412757  0.442038  0.392812  0.456901  0.455032  0.323845  0.413898
# 17  0.411624  0.464890  0.404444  0.453736  0.474530  0.396995  0.434370
# 18  0.426886  0.465306  0.394922  0.442154  0.456946  0.403379  0.431599
# 19  0.441353  0.468839  0.395783  0.436744  0.451922  0.368006  0.427108
#
#          std
# 0   0.029374
# 1   0.032509
# 2   0.060104
# 3   0.059154
# 4   0.042281
# 5   0.041225
# 6   0.069331
# 7   0.073368
# 8   0.058269
# 9   0.069916
# 10  0.066252
# 11  0.059745
# 12  0.045452
# 13  0.048812
# 14  0.042699
# 15  0.044252
# 16  0.046347
# 17  0.030901
# 18  0.025993
# 19  0.034466

# %%
#calculate sparsity for convengence plot
def calculate_sparsity_3d(pareto_front_3d):
    # Flatten the 3D array to 2D for sorting
    pareto_front = pareto_front_3d.reshape(-1, pareto_front_3d.shape[-1])

    # Sort the Pareto front based on the first objective
    sorted_pareto_front = pareto_front[pareto_front[:, 0].argsort()]

    # Calculate the squared distances between consecutive points
    squared_distances = np.sum(np.diff(sorted_pareto_front, axis=0) ** 2, axis=1)

    # Calculate the average squared distance (sparsity)
    sparsity = np.mean(squared_distances)

    return sparsity

# %%
# Initialize the hypervolume lists
final_s = []

# Calculate hypervolumes using pygmo's hypervolume function
for k in range(combined_rewards.shape[0]): #runs
    s = []
    for i in range(combined_rewards.shape[2]): #iterations
        t = []
        for n in range(combined_rewards.shape[1]): #weights
        # Aggregate data for all weights j at the current stage
            t.append(combined_rewards[k,n,i])
        t = np.array(t)
        s.append(calculate_sparsity_3d(t))
    #print(len(h))
    final_s.append(s)

# %%
#print sparsity
df_s = pd.DataFrame(final_s)
df_s = df_s.T

df_s["mean"] = df_s.mean(axis=1)
df_s["std"] = df_s.std(axis=1)

# %%
df_s
# Out:
#            0         1         2         3         4         5      mean  \
# 0   0.001449  0.002218  0.000938  0.000608  0.000233  0.000380  0.000971
# 1   0.001514  0.001370  0.001783  0.001654  0.000357  0.000848  0.001254
# 2   0.003195  0.002766  0.005416  0.001190  0.001649  0.001436  0.002609
# 3   0.001494  0.001529  0.011628  0.003380  0.001749  0.001207  0.003498
# 4   0.002782  0.003985  0.014314  0.001725  0.004249  0.004014  0.005178
# 5   0.003034  0.001695  0.014625  0.005086  0.003934  0.004218  0.005432
# 6   0.005066  0.004647  0.011774  0.003280  0.004808  0.003610  0.005531
# 7   0.009260  0.006064  0.016801  0.003778  0.008065  0.002230  0.007700
# 8   0.013982  0.006068  0.004736  0.003100  0.012133  0.004219  0.007373
# 9   0.015815  0.007384  0.004691  0.004582  0.016229  0.005629  0.009055
# 10  0.031910  0.005299  0.009795  0.003623  0.025600  0.009476  0.014284
# 11  0.022698  0.009169  0.006047  0.006895  0.024462  0.006156  0.012571
# 12  0.023573  0.006030  0.005668  0.005549  0.007275  0.017906  0.011000
# 13  0.033347  0.007686  0.006073  0.007605  0.005998  0.024100  0.014135
# 14  0.025793  0.008619  0.004580  0.008296  0.008746  0.015328  0.011894
# 15  0.045915  0.008490  0.004361  0.005250  0.011929  0.014208  0.015026
# 16  0.041652  0.009369  0.004690  0.006335  0.007940  0.020324  0.015051
# 17  0.044837  0.007972  0.005700  0.006448  0.008220  0.017729  0.015151
# 18  0.060672  0.008972  0.005119  0.005099  0.007507  0.044018  0.021898
# 19  0.035243  0.010124  0.008804  0.004056  0.011289  0.015693  0.014201
#
#          std
# 0   0.000684
# 1   0.000499
# 2   0.001447
# 3   0.003704
# 4   0.004179
# 5   0.004244
# 6   0.002865
# 7   0.004715
# 8   0.004147
# 9   0.005012
# 10  0.010618
# 11  0.007868
# 12  0.007100
# 13  0.010676
# 14  0.006977
# 15  0.014238
# 16  0.012920
# 17  0.013860
# 18  0.022101
# 19  0.010018

# %%
# Initialize the hypervolume lists
final_e = []

# Calculate hypervolumes using pygmo's hypervolume function
for k in range(combined_rewards.shape[0]): #runs
    e = []
    for i in range(combined_rewards.shape[2]): #iterations
        eum = 0
        for n in range(combined_rewards.shape[1]): #weights
        # Aggregate data for all weights j at the current stage
            reward_vector = combined_rewards[k,n,i]
            weights = weight_list[k,n]
            eum += np.dot(reward_vector,weights)
        
        e.append(eum/combined_rewards.shape[1]) #average over weights

    final_e.append(e)

# %%
#print EUM
df_e = pd.DataFrame(final_e)
df_e = df_e.T
df_e["mean"] = df_e.mean(axis=1)
df_e["std"] = df_e.std(axis=1)

# %%
df_e
# Out:
#            0         1         2         3         4         5      mean  \
# 0   0.621083  0.625258  0.640144  0.647191  0.644929  0.642835  0.636907
# 1   0.631595  0.613413  0.633720  0.645995  0.644953  0.633475  0.633858
# 2   0.639464  0.625472  0.625944  0.650144  0.635254  0.633771  0.635008
# 3   0.645619  0.627440  0.610795  0.639746  0.630104  0.652603  0.634385
# 4   0.642813  0.628392  0.613212  0.659091  0.627227  0.650286  0.636837
# 5   0.633918  0.644778  0.621051  0.659948  0.631705  0.650963  0.640394
# 6   0.640843  0.640275  0.616664  0.640994  0.651745  0.647442  0.639661
# 7   0.634458  0.636080  0.614586  0.627600  0.632079  0.664291  0.634849
# 8   0.644023  0.643011  0.609651  0.625418  0.629426  0.650234  0.633627
# 9   0.633740  0.635200  0.609752  0.634695  0.630161  0.655108  0.633109
# 10  0.612622  0.652406  0.599508  0.622772  0.628869  0.655214  0.628565
# 11  0.618890  0.643341  0.609231  0.625306  0.622690  0.649340  0.628133
# 12  0.627255  0.639355  0.608092  0.629198  0.638061  0.656884  0.633141
# 13  0.619133  0.646599  0.610910  0.636060  0.644590  0.646798  0.634015
# 14  0.610128  0.654432  0.613926  0.644127  0.653123  0.655527  0.638544
# 15  0.620975  0.659170  0.613823  0.641565  0.661626  0.644515  0.640279
# 16  0.617337  0.642077  0.615992  0.644219  0.665960  0.635482  0.636844
# 17  0.613467  0.644098  0.609608  0.647416  0.661294  0.642062  0.636324
# 18  0.595609  0.660418  0.614623  0.646490  0.652034  0.640880  0.635009
# 19  0.615006  0.663554  0.607071  0.647527  0.642267  0.644512  0.636656
#
#          std
# 0   0.010015
# 1   0.010752
# 2   0.008403
# 3   0.013601
# 4   0.015458
# 5   0.012941
# 6   0.011098
# 7   0.014940
# 8   0.013735
# 9   0.013200
# 10  0.020045
# 11  0.013912
# 12  0.014743
# 13  0.014101
# 14  0.019140
# 15  0.017817
# 16  0.017062
# 17  0.018602
# 18  0.022619
# 19  0.019489
